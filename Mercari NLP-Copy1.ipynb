# %% [markdown]
# # Mercari NLP

# %%
import tensorflow as tf
# Out:
# 2022-11-09 16:15:34.630320: E tensorflow/core/lib/monitoring/collection_registry.cc:81] Cannot register 2 metrics with the same name: /tensorflow/api/keras/optimizers
# ---------------------------------------------------------------------------
# AlreadyExistsError                        Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 import tensorflow as tf
#
# File ~/miniforge3/envs/tf_test/lib/python3.10/site-packages/tensorflow/__init__.py:479, in <module>
#     477 if hasattr(_current_module, "keras"):
#     478   try:
# --> 479     keras._load()
#     480   except ImportError:
#     481     pass
#
# File ~/miniforge3/envs/tf_test/lib/python3.10/site-packages/tensorflow/python/util/lazy_loader.py:45, in LazyLoader._load(self)
#      43 """Load the module and insert it into the parent's globals."""
#      44 # Import the target module and insert it into the parent's namespace
# ---> 45 module = importlib.import_module(self.__name__)
#      46 self._parent_module_globals[self._local_name] = module
#      48 # Emit a warning if one was specified
#
# File ~/miniforge3/envs/tf_test/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/miniforge3/envs/tf_test/lib/python3.10/site-packages/keras/__init__.py:25, in <module>
#      22 from keras import distribute
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from keras import models
#      27 from keras.engine.input_layer import Input
#      28 from keras.engine.sequential import Sequential
#
# File ~/miniforge3/envs/tf_test/lib/python3.10/site-packages/keras/models/__init__.py:18, in <module>
#       1 # Copyright 2022 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Keras models API."""
# ---> 18 from keras.engine.functional import Functional
#      19 from keras.engine.sequential import Sequential
#      20 from keras.engine.training import Model
#
# File ~/miniforge3/envs/tf_test/lib/python3.10/site-packages/keras/engine/functional.py:25, in <module>
#      23 import warnings
#      24 from keras import backend
# ---> 25 from keras.engine import base_layer
#      26 from keras.engine import base_layer_utils
#      27 from keras.engine import functional_utils
#
# File ~/miniforge3/envs/tf_test/lib/python3.10/site-packages/keras/engine/base_layer.py:43, in <module>
#      41 from keras.engine import node as node_module
#      42 from keras.mixed_precision import autocast_variable
# ---> 43 from keras.mixed_precision import loss_scale_optimizer
#      44 from keras.mixed_precision import policy
#      45 from keras.saving.saved_model import layer_serialization
#
# File ~/miniforge3/envs/tf_test/lib/python3.10/site-packages/keras/mixed_precision/loss_scale_optimizer.py:20, in <module>
#      18 from keras import optimizers
#      19 from keras.mixed_precision import loss_scale as keras_loss_scale_module
# ---> 20 from keras.optimizer_v2 import optimizer_v2
#      21 from keras.optimizer_v2 import utils as optimizer_utils
#      23 import tensorflow.compat.v2 as tf
#
# File ~/miniforge3/envs/tf_test/lib/python3.10/site-packages/keras/optimizer_v2/optimizer_v2.py:36, in <module>
#      32 from keras.utils import tf_utils
#      33 from tensorflow.python.util.tf_export import keras_export
# ---> 36 keras_optimizers_gauge = tf.__internal__.monitoring.BoolGauge(
#      37     "/tensorflow/api/keras/optimizers", "keras optimizer usage", "method")
#      39 _DEFAULT_VALID_DTYPES = frozenset([
#      40     tf.float16, tf.bfloat16, tf.float32, tf.float64,
#      41     tf.complex64, tf.complex128
#      42 ])
#      45 def _deduplicate_indexed_slices(values, indices):
#
# File ~/miniforge3/envs/tf_test/lib/python3.10/site-packages/tensorflow/python/eager/monitoring.py:360, in BoolGauge.__init__(self, name, description, *labels)
#     352 def __init__(self, name, description, *labels):
#     353   """Creates a new BoolGauge.
#     354
#     355   Args:
#    (...)
#     358     *labels: The label list of the new metric.
#     359   """
# --> 360   super(BoolGauge, self).__init__('BoolGauge', _bool_gauge_methods,
#     361                                   len(labels), name, description, *labels)
#
# File ~/miniforge3/envs/tf_test/lib/python3.10/site-packages/tensorflow/python/eager/monitoring.py:135, in Metric.__init__(self, metric_name, metric_methods, label_length, *args)
#     131 if label_length >= len(self._metric_methods):
#     132   raise ValueError('Cannot create {} metric with label >= {}'.format(
#     133       self._metric_name, len(self._metric_methods)))
# --> 135 self._metric = self._metric_methods[self._label_length].create(*args)
#
# AlreadyExistsError: Another metric with the same name already exists.

# %%
#Standard imports
import pandas as pd
import os
import sys
import string
import re
import numpy as np

# %%
#Visualizations
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 #Visualizations
# ----> 2 import matplotlib.pyplot as plt
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#       4 import seaborn as sns
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# 2022-11-09 15:42:05.597225: E tensorflow/core/lib/monitoring/collection_registry.cc:81] Cannot register 2 metrics with the same name: /tensorflow/api/keras/optimizers
# ---------------------------------------------------------------------------
# AlreadyExistsError                        Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 import tensorflow as tf
#       2 from tensorflow import keras
#       3 from tensorflow.keras import layers
#
# File ~/miniforge3/envs/tf_test/lib/python3.10/site-packages/tensorflow/__init__.py:479, in <module>
#     477 if hasattr(_current_module, "keras"):
#     478   try:
# --> 479     keras._load()
#     480   except ImportError:
#     481     pass
#
# File ~/miniforge3/envs/tf_test/lib/python3.10/site-packages/tensorflow/python/util/lazy_loader.py:45, in LazyLoader._load(self)
#      43 """Load the module and insert it into the parent's globals."""
#      44 # Import the target module and insert it into the parent's namespace
# ---> 45 module = importlib.import_module(self.__name__)
#      46 self._parent_module_globals[self._local_name] = module
#      48 # Emit a warning if one was specified
#
# File ~/miniforge3/envs/tf_test/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/miniforge3/envs/tf_test/lib/python3.10/site-packages/keras/__init__.py:25, in <module>
#      22 from keras import distribute
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from keras import models
#      27 from keras.engine.input_layer import Input
#      28 from keras.engine.sequential import Sequential
#
# File ~/miniforge3/envs/tf_test/lib/python3.10/site-packages/keras/models/__init__.py:18, in <module>
#       1 # Copyright 2022 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Keras models API."""
# ---> 18 from keras.engine.functional import Functional
#      19 from keras.engine.sequential import Sequential
#      20 from keras.engine.training import Model
#
# File ~/miniforge3/envs/tf_test/lib/python3.10/site-packages/keras/engine/functional.py:25, in <module>
#      23 import warnings
#      24 from keras import backend
# ---> 25 from keras.engine import base_layer
#      26 from keras.engine import base_layer_utils
#      27 from keras.engine import functional_utils
#
# File ~/miniforge3/envs/tf_test/lib/python3.10/site-packages/keras/engine/base_layer.py:43, in <module>
#      41 from keras.engine import node as node_module
#      42 from keras.mixed_precision import autocast_variable
# ---> 43 from keras.mixed_precision import loss_scale_optimizer
#      44 from keras.mixed_precision import policy
#      45 from keras.saving.saved_model import layer_serialization
#
# File ~/miniforge3/envs/tf_test/lib/python3.10/site-packages/keras/mixed_precision/loss_scale_optimizer.py:20, in <module>
#      18 from keras import optimizers
#      19 from keras.mixed_precision import loss_scale as keras_loss_scale_module
# ---> 20 from keras.optimizer_v2 import optimizer_v2
#      21 from keras.optimizer_v2 import utils as optimizer_utils
#      23 import tensorflow.compat.v2 as tf
#
# File ~/miniforge3/envs/tf_test/lib/python3.10/site-packages/keras/optimizer_v2/optimizer_v2.py:36, in <module>
#      32 from keras.utils import tf_utils
#      33 from tensorflow.python.util.tf_export import keras_export
# ---> 36 keras_optimizers_gauge = tf.__internal__.monitoring.BoolGauge(
#      37     "/tensorflow/api/keras/optimizers", "keras optimizer usage", "method")
#      39 _DEFAULT_VALID_DTYPES = frozenset([
#      40     tf.float16, tf.bfloat16, tf.float32, tf.float64,
#      41     tf.complex64, tf.complex128
#      42 ])
#      45 def _deduplicate_indexed_slices(values, indices):
#
# File ~/miniforge3/envs/tf_test/lib/python3.10/site-packages/tensorflow/python/eager/monitoring.py:360, in BoolGauge.__init__(self, name, description, *labels)
#     352 def __init__(self, name, description, *labels):
#     353   """Creates a new BoolGauge.
#     354
#     355   Args:
#    (...)
#     358     *labels: The label list of the new metric.
#     359   """
# --> 360   super(BoolGauge, self).__init__('BoolGauge', _bool_gauge_methods,
#     361                                   len(labels), name, description, *labels)
#
# File ~/miniforge3/envs/tf_test/lib/python3.10/site-packages/tensorflow/python/eager/monitoring.py:135, in Metric.__init__(self, metric_name, metric_methods, label_length, *args)
#     131 if label_length >= len(self._metric_methods):
#     132   raise ValueError('Cannot create {} metric with label >= {}'.format(
#     133       self._metric_name, len(self._metric_methods)))
# --> 135 self._metric = self._metric_methods[self._label_length].create(*args)
#
# AlreadyExistsError: Another metric with the same name already exists.

# %%
from sklearn.datasets import load_iris
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 from sklearn.datasets import load_iris
#
# File ~/miniforge3/lib/python3.10/site-packages/sklearn/__init__.py:82, in <module>
#      80 from . import _distributor_init  # noqa: F401
#      81 from . import __check_build  # noqa: F401
# ---> 82 from .base import clone
#      83 from .utils._show_versions import show_versions
#      85 __all__ = [
#      86     "calibration",
#      87     "cluster",
#    (...)
#     128     "show_versions",
#     129 ]
#
# File ~/miniforge3/lib/python3.10/site-packages/sklearn/base.py:17, in <module>
#      15 from . import __version__
#      16 from ._config import get_config
# ---> 17 from .utils import _IS_32BIT
#      18 from .utils._tags import (
#      19     _DEFAULT_TAGS,
#      20 )
#      21 from .utils.validation import check_X_y
#
# File ~/miniforge3/lib/python3.10/site-packages/sklearn/utils/__init__.py:22, in <module>
#      20 import warnings
#      21 import numpy as np
# ---> 22 from scipy.sparse import issparse
#      24 from .murmurhash import murmurhash3_32
#      25 from .class_weight import compute_class_weight, compute_sample_weight
#
# File ~/miniforge3/lib/python3.10/site-packages/scipy/sparse/__init__.py:283, in <module>
#     278 from ._arrays import (
#     279     csr_array, csc_array, lil_array, dok_array, coo_array, dia_array, bsr_array
#     280 )
#     282 # For backward compatibility with v0.19.
# --> 283 from . import csgraph
#     285 # Deprecated namespaces, to be removed in v2.0.0
#     286 from . import (
#     287     base, bsr, compressed, construct, coo, csc, csr, data, dia, dok, extract,
#     288     lil, sparsetools, sputils
#     289 )
#
# File ~/miniforge3/lib/python3.10/site-packages/scipy/sparse/csgraph/__init__.py:182, in <module>
#     154 __docformat__ = "restructuredtext en"
#     156 __all__ = ['connected_components',
#     157            'laplacian',
#     158            'shortest_path',
#    (...)
#     179            'csgraph_to_masked',
#     180            'NegativeCycleError']
# --> 182 from ._laplacian import laplacian
#     183 from ._shortest_path import (
#     184     shortest_path, floyd_warshall, dijkstra, bellman_ford, johnson,
#     185     NegativeCycleError
#     186 )
#     187 from ._traversal import (
#     188     breadth_first_order, depth_first_order, breadth_first_tree,
#     189     depth_first_tree, connected_components
#     190 )
#
# File ~/miniforge3/lib/python3.10/site-packages/scipy/sparse/csgraph/_laplacian.py:7, in <module>
#       5 import numpy as np
#       6 from scipy.sparse import isspmatrix
# ----> 7 from scipy.sparse.linalg import LinearOperator
#      10 ###############################################################################
#      11 # Graph laplacian
#      12 def laplacian(
#      13     csgraph,
#      14     normed=False,
#    (...)
#      21     symmetrized=False,
#      22 ):
#
# File ~/miniforge3/lib/python3.10/site-packages/scipy/sparse/linalg/__init__.py:120, in <module>
#       1 """
#       2 Sparse linear algebra (:mod:`scipy.sparse.linalg`)
#       3 ==================================================
#    (...)
#     117
#     118 """
# --> 120 from ._isolve import *
#     121 from ._dsolve import *
#     122 from ._interface import *
#
# File ~/miniforge3/lib/python3.10/site-packages/scipy/sparse/linalg/_isolve/__init__.py:4, in <module>
#       1 "Iterative Solvers for Sparse Linear Systems"
#       3 #from info import __doc__
# ----> 4 from .iterative import *
#       5 from .minres import minres
#       6 from .lgmres import lgmres
#
# File ~/miniforge3/lib/python3.10/site-packages/scipy/sparse/linalg/_isolve/iterative.py:9, in <module>
#       6 from textwrap import dedent
#       7 import numpy as np
# ----> 9 from . import _iterative
#      11 from scipy.sparse.linalg._interface import LinearOperator
#      12 from .utils import make_system
#
# ImportError: dlopen(/Users/javm/miniforge3/lib/python3.10/site-packages/scipy/sparse/linalg/_isolve/_iterative.cpython-310-darwin.so, 0x0002): Library not loaded: @rpath/liblapack.3.dylib
#   Referenced from: <78036CAA-82A0-3FC2-9DF1-A2F5970A489B> /Users/javm/miniforge3/lib/python3.10/site-packages/scipy/sparse/linalg/_isolve/_iterative.cpython-310-darwin.so
#   Reason: tried: '/Users/javm/miniforge3/lib/python3.10/site-packages/scipy/sparse/linalg/_isolve/liblapack.3.dylib' (no such file), '/Users/javm/miniforge3/lib/python3.10/site-packages/scipy/sparse/linalg/_isolve/../../../../../../liblapack.3.dylib' (no such file), '/Users/javm/miniforge3/lib/python3.10/site-packages/scipy/sparse/linalg/_isolve/liblapack.3.dylib' (no such file), '/Users/javm/miniforge3/lib/python3.10/site-packages/scipy/sparse/linalg/_isolve/../../../../../../liblapack.3.dylib' (no such file), '/Users/javm/miniforge3/bin/../lib/liblapack.3.dylib' (no such file), '/Users/javm/miniforge3/bin/../lib/liblapack.3.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS@rpath/liblapack.3.dylib' (no such file), '/Users/javm/miniforge3/lib/python3.10/site-packages/scipy/sparse/linalg/_isolve/liblapack.3.dylib' (no such file), '/Users/javm/miniforge3/lib/python3.10/site-packages/scipy/sparse/linalg/_isolve/../../../../../../liblapack.3.dylib' (no such file), '/Users/javm/miniforge3/lib/python3.10/site-packages/scipy/sparse/linalg/_isolve/liblapack.3.dylib' (no such file), '/Users/javm/miniforge3/lib/python3.10/site-packages/scipy/sparse/linalg/_isolve/../../../../../../liblapack.3.dylib' (no such file), '/Users/javm/miniforge3/bin/../lib/liblapack.3.dylib' (no such file), '/Users/javm/miniforge3/bin/../lib/liblapack.3.dylib' (no such file), '/usr/local/lib/liblapack.3.dylib' (no such file), '/usr/lib/liblapack.3.dylib' (no such file, not in dyld cache)

# %%
train_df = pd.read_csv("/Users/javm/Desktop/Mercari-Price-Prediction-Project/train.tsv", sep = '\t')

# %%
train_df
# Out:
#          train_id                                   name  item_condition_id  \
# 0               0    MLB Cincinnati Reds T Shirt Size XL                  3
# 1               1       Razer BlackWidow Chroma Keyboard                  3
# 2               2                         AVA-VIV Blouse                  1
# 3               3                  Leather Horse Statues                  1
# 4               4                   24K GOLD plated rose                  1
# ...           ...                                    ...                ...
# 1482530   1482530             Free People Inspired Dress                  2
# 1482531   1482531          Little mermaid handmade dress                  2
# 1482532   1482532  21 day fix containers and eating plan                  2
# 1482533   1482533                 World markets lanterns                  3
# 1482534   1482534          Brand new lux de ville wallet                  1
#
#                                              category_name   brand_name  \
# 0                                        Men/Tops/T-shirts          NaN
# 1        Electronics/Computers & Tablets/Components & P...        Razer
# 2                              Women/Tops & Blouses/Blouse       Target
# 3                       Home/Home Décor/Home Décor Accents          NaN
# 4                                  Women/Jewelry/Necklaces          NaN
# ...                                                    ...          ...
# 1482530                             Women/Dresses/Mid-Calf  Free People
# 1482531                           Kids/Girls 2T-5T/Dresses       Disney
# 1482532     Sports & Outdoors/Exercise/Fitness accessories          NaN
# 1482533                 Home/Home Décor/Home Décor Accents          NaN
# 1482534                  Women/Women's Accessories/Wallets          NaN
#
#          price  shipping                                   item_description
# 0         10.0         1                                 No description yet
# 1         52.0         0  This keyboard is in great condition and works ...
# 2         10.0         1  Adorable top with a hint of lace and a key hol...
# 3         35.0         1  New with tags. Leather horses. Retail for [rm]...
# 4         44.0         0          Complete with certificate of authenticity
# ...        ...       ...                                                ...
# 1482530   20.0         1  Lace, says size small but fits medium perfectl...
# 1482531   14.0         0   Little mermaid handmade dress never worn size 2t
# 1482532   12.0         0          Used once or twice, still in great shape.
# 1482533   45.0         1  There is 2 of each one that you see! So 2 red ...
# 1482534   22.0         0  New with tag, red with sparkle. Firm price, no...
#
# [1482535 rows x 8 columns]

# %%
train_df = train_df.groupby('category_name').filter(lambda x : len(x)>5000)

# %%
train_df
# Out:
#          train_id                                   name  item_condition_id  \
# 0               0    MLB Cincinnati Reds T Shirt Size XL                  3
# 2               2                         AVA-VIV Blouse                  1
# 3               3                  Leather Horse Statues                  1
# 4               4                   24K GOLD plated rose                  1
# 5               5       Bundled items requested for Ruie                  3
# ...           ...                                    ...                ...
# 1482526   1482526   Harry Potter Shirt! Women M/ Girl XL                  2
# 1482527   1482527  Blk/white ribbed mock neck bodysuit M                  1
# 1482528   1482528    Victoria's Secret Tankini Sz. Large                  2
# 1482533   1482533                 World markets lanterns                  3
# 1482534   1482534          Brand new lux de ville wallet                  1
#
#                               category_name         brand_name  price  \
# 0                         Men/Tops/T-shirts                NaN   10.0
# 2               Women/Tops & Blouses/Blouse             Target   10.0
# 3        Home/Home Décor/Home Décor Accents                NaN   35.0
# 4                   Women/Jewelry/Necklaces                NaN   44.0
# 5                         Women/Other/Other                NaN   59.0
# ...                                     ...                ...    ...
# 1482526       Women/Tops & Blouses/T-Shirts                NaN   12.0
# 1482527         Women/Tops & Blouses/Blouse                NaN   10.0
# 1482528  Women/Athletic Apparel/Sports Bras  Victoria's Secret   18.0
# 1482533  Home/Home Décor/Home Décor Accents                NaN   45.0
# 1482534   Women/Women's Accessories/Wallets                NaN   22.0
#
#          shipping                                   item_description
# 0               1                                 No description yet
# 2               1  Adorable top with a hint of lace and a key hol...
# 3               1  New with tags. Leather horses. Retail for [rm]...
# 4               0          Complete with certificate of authenticity
# 5               0  Banana republic bottoms, Candies skirt with ma...
# ...           ...                                                ...
# 1482526         0  Great Harry Potter Shirt! "Hogwarts, School of...
# 1482527         1  Brand new black and white ribbed mock neck bod...
# 1482528         1  Purple and Paisley Victoria's Secret Tankini S...
# 1482533         1  There is 2 of each one that you see! So 2 red ...
# 1482534         0  New with tag, red with sparkle. Firm price, no...
#
# [966236 rows x 8 columns]

# %%
train_df['category_name'].value_counts()
# Out:
# Women/Athletic Apparel/Pants, Tights, Leggings    60177
# Women/Tops & Blouses/T-Shirts                     46380
# Beauty/Makeup/Face                                34335
# Beauty/Makeup/Lips                                29910
# Electronics/Video Games & Consoles/Games          26557
#                                                   ...
# Kids/Boys 0-24 Mos/One-Pieces                      5205
# Home/Kitchen & Dining/Dining & Entertaining        5130
# Beauty/Bath & Body/Bath                            5049
# Men/Shoes/Fashion Sneakers                         5039
# Home/Home Décor/Home Fragrance                     5015
# Name: category_name, Length: 76, dtype: int64

# %%
y = df['price']
X = df.drop(columns = ['price'])

# %%
#this is optimized for a binary classifier and is a cnn, to do a baseline i would just have one hidden layer:
#more simpler model:
model = Sequential()
model.add(Input(shape= (number of dimensions in data)))
model.add(Dense(128, activation=‘relu’))
model.add(Dense(1, activation=‘sigmoid’))
model.compile(loss=‘binary_crossentropy’,
              optimizer=‘adam’, metrics=‘accuracy’)
model.summary()
